# %% [markdown]
# Texture Synthesis Using Wavelets================================*Important:* Please read the [installation page](http://gpeyre.github.io/numerical-tours/installation_python/) for details about how to install the toolboxes.$\newcommand{\dotp}[2]{\langle #1, #2 \rangle}$$\newcommand{\enscond}[2]{\lbrace #1, #2 \rbrace}$$\newcommand{\pd}[2]{ \frac{ \partial #1}{\partial #2} }$$\newcommand{\umin}[1]{\underset{#1}{\min}\;}$$\newcommand{\umax}[1]{\underset{#1}{\max}\;}$$\newcommand{\umin}[1]{\underset{#1}{\min}\;}$$\newcommand{\uargmin}[1]{\underset{#1}{argmin}\;}$$\newcommand{\norm}[1]{\|#1\|}$$\newcommand{\abs}[1]{\left|#1\right|}$$\newcommand{\choice}[1]{ \left\{  \begin{array}{l} #1 \end{array} \right. }$$\newcommand{\pa}[1]{\left(#1\right)}$$\newcommand{\diag}[1]{{diag}\left( #1 \right)}$$\newcommand{\qandq}{\quad\text{and}\quad}$$\newcommand{\qwhereq}{\quad\text{where}\quad}$$\newcommand{\qifq}{ \quad \text{if} \quad }$$\newcommand{\qarrq}{ \quad \Longrightarrow \quad }$$\newcommand{\ZZ}{\mathbb{Z}}$$\newcommand{\CC}{\mathbb{C}}$$\newcommand{\RR}{\mathbb{R}}$$\newcommand{\EE}{\mathbb{E}}$$\newcommand{\Zz}{\mathcal{Z}}$$\newcommand{\Ww}{\mathcal{W}}$$\newcommand{\Vv}{\mathcal{V}}$$\newcommand{\Nn}{\mathcal{N}}$$\newcommand{\NN}{\mathcal{N}}$$\newcommand{\Hh}{\mathcal{H}}$$\newcommand{\Bb}{\mathcal{B}}$$\newcommand{\Ee}{\mathcal{E}}$$\newcommand{\Cc}{\mathcal{C}}$$\newcommand{\Gg}{\mathcal{G}}$$\newcommand{\Ss}{\mathcal{S}}$$\newcommand{\Pp}{\mathcal{P}}$$\newcommand{\Ff}{\mathcal{F}}$$\newcommand{\Xx}{\mathcal{X}}$$\newcommand{\Mm}{\mathcal{M}}$$\newcommand{\Ii}{\mathcal{I}}$$\newcommand{\Dd}{\mathcal{D}}$$\newcommand{\Ll}{\mathcal{L}}$$\newcommand{\Tt}{\mathcal{T}}$$\newcommand{\si}{\sigma}$$\newcommand{\al}{\alpha}$$\newcommand{\la}{\lambda}$$\newcommand{\ga}{\gamma}$$\newcommand{\Ga}{\Gamma}$$\newcommand{\La}{\Lambda}$$\newcommand{\si}{\sigma}$$\newcommand{\Si}{\Sigma}$$\newcommand{\be}{\beta}$$\newcommand{\de}{\delta}$$\newcommand{\De}{\Delta}$$\newcommand{\phi}{\varphi}$$\newcommand{\th}{\theta}$$\newcommand{\om}{\omega}$$\newcommand{\Om}{\Omega}$

# %% [markdown]
# This numerical tour explores texture synthesis using wavelets.Image synthesis is obtained by drawing an image at random that satisfiessome modeling constraint, that are usually learned from a given exemplartexture.

# %%
from __future__ import divisionimport nt_toolbox as ntfrom nt_solutions import graphics_2_synthesis_wavelets as solutions%matplotlib inline%load_ext autoreload%autoreload 2

# %% [markdown]
# Multi-scale Texture Synthesis-----------------------------The decay of wavelet coefficients caraterize pointwise singularities inimages and texture. Histogram equalization enable the synthesis oftexture with singularities. This corresponds to the texture synthesisalgorithm of Heeger and Bergen.Load a texture.

# %%
n = 512name = 'texture'M = load_image(name, n)M = rescale(sum(M, 3))

# %% [markdown]
# *For Scilab users*: you should increase the size of the memory._Warning_: execute this line only once.

# %%
extend_stack_size(4)

# %% [markdown]
# First we compute the wavelet coefficients of the texture.We use a translation invariant transform.

# %%
options.ti = 1Jmin = 4MW = perform_wavelet_transf(M(: , : , 1), Jmin, + 1, options)

# %% [markdown]
# We initialize the synthesis by a random noise with the same gray values.

# %%
M1 = perform_hist_eq(randn(n, n), M)

# %% [markdown]
# Display.

# %%
imageplot(M, 'Exemplar', 1, 2, 1)imageplot(M1, 'Initial noise', 1, 2, 2)

# %% [markdown]
# We also compute the wavelet transform of the noise.

# %%
MW1 = perform_wavelet_transf(M1, Jmin, + 1, options)

# %% [markdown]
# A random texture is obtained by histogram equalization of each waveletscale.

# %%
for i in 1: size(MW, 3):    MW1(: , : , i) = perform_hist_eq(MW1(: , : , i), MW(: , : , i))

# %% [markdown]
# We retrieve the texture by inverse wavelet transform.

# %%
M1 = perform_wavelet_transf(MW1, Jmin, -1, options)

# %% [markdown]
# Display.

# %%
imageplot(M, 'Exemplar', 1, 2, 1)imageplot(M1, 'Initial synthesis', 1, 2, 2)

# %% [markdown]
# __Exercise 1__Iterate these two steps (spatial and wavelet histogram matching) until convergence to a stable step.pacial matching

# %%
solutions.exo1()

# %%
## Insert your code here.

# %% [markdown]
# Multi-scale Color Texture Synthesis-----------------------------------It is possible to perform color synthesis by synthesizing independantlyeach channel over a well chosen color space.Load a color texture.

# %%
n = 512M = rescale(load_image('texture', n))

# %% [markdown]
# __Exercise 2__Perform color texture synthesis with wavelets over the RGB space.isplay.

# %%
solutions.exo2()

# %%
## Insert your code here.

# %% [markdown]
# __Exercise 3__Try with other color spaces, for instance PCA adapte space.

# %%
solutions.exo3()

# %%
## Insert your code here.

# %% [markdown]
# Multi-dimensional Color Equalization------------------------------------To maintain color consistency, it is possible to use a colorequalization.Initial image.

# %%
M1 = randn(n, n, 3)

# %% [markdown]
# A simple (but not very acurate) method to perform in performingindependant channel equalization over randomized color space.This needs to be repeated several time to converge to a real matching.Compute a random 3x3 orthogonal matrix.

# %%
[U, R] = qr(randn(3))

# %% [markdown]
# Perform the change of color space.

# %%
d = reshape(M, [n^2 3])*Ud1 = reshape(M1, [n^2 3])*U

# %% [markdown]
# Perform the equalization

# %%
for c in 1: 3:    d1(: , c) = perform_hist_eq(d1(: , c), d(: , c))

# %% [markdown]
# Perform the inverse change of color space.

# %%
M1 = reshape(d1*U', [n n 3])

# %% [markdown]
# Compares the histogram of the R channel. You can see that the match isimperfect.

# %%
m = M(: , : , 1); m1 = M1(: , : , 1)subplot(2, 1, 1)hist(m(: ), 50); title('Original')subplot(2, 1, 2)hist(clamp(m1(: )), 50); title('Matched')

# %%
M1 = randn(n, n, 3)for i in 1: 3:    M1(: , : , i) = perform_hist_eq(M1(: , : , i), M(: , : , i))

# %% [markdown]
# __Exercise 4__Perform iteratively the randomized matching. Plot the decay of themathing error.

# %%
solutions.exo4()

# %%
## Insert your code here.

# %% [markdown]
# Display the histograms of the R channels. The match is not perfect,but it is better than with a single projection.

# %%
m = M(: , : , 1); m1 = M1(: , : , 1)subplot(2, 1, 1)hist(m(: ), 50); title('Original')subplot(2, 1, 2)hist(clamp(m1(: )), 50); title('Matched')

# %% [markdown]
# Display the equalized color image;

# %%
imageplot(M, 'Image', 1, 2, 1)imageplot(M1, 'Equalized', 1, 2, 2)

# %% [markdown]
# __Exercise 5__Perform color texture synthesis with wavelets using this color histogrammatching at each iteration.recompute the wavelet transform of the imageisplay.

# %%
solutions.exo5()

# %%
## Insert your code here.
