# %% [markdown]
# Volumetric wavelet Data Processing==================================*Important:* Please read the [installation page](http://gpeyre.github.io/numerical-tours/installation_python/) for details about how to install the toolboxes.$\newcommand{\dotp}[2]{\langle #1, #2 \rangle}$$\newcommand{\enscond}[2]{\lbrace #1, #2 \rbrace}$$\newcommand{\pd}[2]{ \frac{ \partial #1}{\partial #2} }$$\newcommand{\umin}[1]{\underset{#1}{\min}\;}$$\newcommand{\umax}[1]{\underset{#1}{\max}\;}$$\newcommand{\umin}[1]{\underset{#1}{\min}\;}$$\newcommand{\uargmin}[1]{\underset{#1}{argmin}\;}$$\newcommand{\norm}[1]{\|#1\|}$$\newcommand{\abs}[1]{\left|#1\right|}$$\newcommand{\choice}[1]{ \left\{  \begin{array}{l} #1 \end{array} \right. }$$\newcommand{\pa}[1]{\left(#1\right)}$$\newcommand{\diag}[1]{{diag}\left( #1 \right)}$$\newcommand{\qandq}{\quad\text{and}\quad}$$\newcommand{\qwhereq}{\quad\text{where}\quad}$$\newcommand{\qifq}{ \quad \text{if} \quad }$$\newcommand{\qarrq}{ \quad \Longrightarrow \quad }$$\newcommand{\ZZ}{\mathbb{Z}}$$\newcommand{\CC}{\mathbb{C}}$$\newcommand{\RR}{\mathbb{R}}$$\newcommand{\EE}{\mathbb{E}}$$\newcommand{\Zz}{\mathcal{Z}}$$\newcommand{\Ww}{\mathcal{W}}$$\newcommand{\Vv}{\mathcal{V}}$$\newcommand{\Nn}{\mathcal{N}}$$\newcommand{\NN}{\mathcal{N}}$$\newcommand{\Hh}{\mathcal{H}}$$\newcommand{\Bb}{\mathcal{B}}$$\newcommand{\Ee}{\mathcal{E}}$$\newcommand{\Cc}{\mathcal{C}}$$\newcommand{\Gg}{\mathcal{G}}$$\newcommand{\Ss}{\mathcal{S}}$$\newcommand{\Pp}{\mathcal{P}}$$\newcommand{\Ff}{\mathcal{F}}$$\newcommand{\Xx}{\mathcal{X}}$$\newcommand{\Mm}{\mathcal{M}}$$\newcommand{\Ii}{\mathcal{I}}$$\newcommand{\Dd}{\mathcal{D}}$$\newcommand{\Ll}{\mathcal{L}}$$\newcommand{\Tt}{\mathcal{T}}$$\newcommand{\si}{\sigma}$$\newcommand{\al}{\alpha}$$\newcommand{\la}{\lambda}$$\newcommand{\ga}{\gamma}$$\newcommand{\Ga}{\Gamma}$$\newcommand{\La}{\Lambda}$$\newcommand{\si}{\sigma}$$\newcommand{\Si}{\Sigma}$$\newcommand{\be}{\beta}$$\newcommand{\de}{\delta}$$\newcommand{\De}{\Delta}$$\newcommand{\phi}{\varphi}$$\newcommand{\th}{\theta}$$\newcommand{\om}{\omega}$$\newcommand{\Om}{\Omega}$

# %% [markdown]
# This numerical tour explores volumetric (3D) data processing.

# %%
from __future__ import divisionimport nt_toolbox as ntfrom nt_solutions import multidim_2_volumetric as solutions%matplotlib inline%load_ext autoreload%autoreload 2

# %% [markdown]
# For Scilab user (otherwise there is not enough memory).WARNING: you should extend the stack size only ONCE.

# %%
extend_stack_size(10)

# %% [markdown]
# 3D Volumetric Datasets----------------------We load a volumetric data.

# %%
name = 'vessels'options.nbdims = 3M = read_bin(name, options)M = rescale(M)

# %% [markdown]
# size of the image (here it is a cube).

# %%
n = size(M, 1)

# %% [markdown]
# We can display some horizontal slices.

# %%
slices = round(linspace(10, n-10, 4))for i in 1: length(slices):    s = slices(i)    imageplot(M(: , : , s), strcat(['Z = ' num2str(s)]), 2, 2, i)

# %% [markdown]
# We can display an isosurface of the dataset (here we sub-sample to speedup the computation).

# %%
sel = 1: 2: nisosurface(M(sel, sel, sel), .5)axis('off')

# %% [markdown]
# 3D Haar Transform-----------------An isotropic 3D Haar transform recursively extract details waveletcoefficients by performing local averages/differences along the X/Y/Z axis.We apply a step of Haar transform in the X/Y/Z directioninitialize the transform

# %%
MW = M

# %% [markdown]
# average/difference along X

# %%
MW = cat3(1, (MW(1: 2: n, : , : ) + MW(2: 2: n, : , : ))/ sqrt(2), (MW(1: 2: n, : , : )-MW(2: 2: n, : , : ))/ sqrt(2))

# %% [markdown]
# average/difference along Y

# %%
MW = cat3(2, (MW(: , 1: 2: n, : ) + MW(: , 2: 2: n, : ))/ sqrt(2), (MW(: , 1: 2: n, : )-MW(: , 2: 2: n, : ))/ sqrt(2))

# %% [markdown]
# average/difference along Z

# %%
MW = cat3(3, (MW(: , : , 1: 2: n) + MW(: , : , 2: 2: n))/ sqrt(2), (MW(: , : , 1: 2: n)-MW(: , : , 2: 2: n))/ sqrt(2))

# %% [markdown]
# Display a horizontal and vertical slice to see the structure of the coefficients.

# %%
imageplot(MW(: , : , 30), 'Horizontal slice', 1, 2, 1)imageplot(squeeze(MW(: , 30, : )), 'Vertical slice', 1, 2, 2)

# %% [markdown]
# __Exercise 1__Implement the forward wavelet transform by iteratively applying thesetransform steps to the low pass residual.nitialize the transform

# %%
solutions.exo1()

# %%
## Insert your code here.

# %% [markdown]
# Volumetric Data Haar Approximation----------------------------------An approximation is obtained by keeping only the largest coefficients.We threshold the coefficients to perform |m|-term approximation.number of kept coefficients

# %%
m = round(.01*n^3)MWT = perform_thresholding(MW, m, 'largest')

# %% [markdown]
# __Exercise 2__Implement the backward transform to compute an approximation |M1| fromthe coefficients |MWT|.

# %%
solutions.exo2()

# %%
## Insert your code here.

# %% [markdown]
# Display the approximation as slices.

# %%
s = 30imageplot(M(: , : , s), 'Original', 1, 2, 1)imageplot(clamp(M1(: , : , s)), 'Approximation', 1, 2, 2)

# %% [markdown]
# Display the approximated isosurface.

# %%
sel = 1: 2: nisosurface(M1(sel, sel, sel), .5)axis('off')

# %% [markdown]
# Linear Volumetric Denoising ----------------------------Linear denoising is obtained by low pass filtering.We add a Gaussian noise to the image.noise level.

# %%
sigma = .06Mnoisy = M + sigma*randn(n, n, n)

# %% [markdown]
# Display slices of the noisy data.

# %%
imageplot(Mnoisy(: , : , n/ 2), 'X slice', 1, 2, 1)imageplot(squeeze(Mnoisy(: , n/ 2, : )), 'Y slice', 1, 2, 2)

# %% [markdown]
# A simple denoising method performs a linear filtering of the data.We build a Gaussian filter of width |sigma|.construct a 3D grid

# %%
x = -n/ 2: n/ 2-1[X, Y, Z] = ndgrid(x, x, x)

# %% [markdown]
# gaussian filter

# %%
s = 2; % widthh = exp(-(X.^2 + Y.^2 + Z.^2)/ (2*s^2))h = h/ sum(h(: ))

# %% [markdown]
# The filtering is computed over the Fourier domain.

# %%
Mh = real(ifftn(fftn(Mnoisy) .* fftn(fftshift(h))))

# %% [markdown]
# Display denoised slices.

# %%
i = 40imageplot(Mnoisy(: , : , i), 'Noisy', 1, 2, 1)imageplot(Mh(: , : , i), 'Denoised', 1, 2, 2)

# %% [markdown]
# Display denoised iso-surface.

# %%
sel = 1: 2: nisosurface(Mh(sel, sel, sel), .5)axis('off')

# %% [markdown]
# __Exercise 3__Select the optimal blurring width |s| to reach the smallest possibleSNR. Keep the optimal denoising |Mblur|

# %%
solutions.exo3()

# %%
## Insert your code here.

# %% [markdown]
# Display optimally denoised iso-surface.

# %%
sel = 1: 2: nisosurface(Mblur(sel, sel, sel), .5)axis('off')title(['Filtering, SNR = ' num2str(snr(M, Mblur), 3) 'dB'])

# %% [markdown]
# Non-Linear Wavelet Volumetric Denoising ----------------------------------------Denoising is obtained by removing small amplitude coefficients thatcorresponds to noise.

# %% [markdown]
# __Exercise 4__Perforn Wavelet denoising by thresholding the wavelet coefficients ofMnoisy. Test both hard thresholding and soft thresholding to determinethe optimal threshold and the corresponding SNR.Record the optimal result |Mwav|.

# %%
solutions.exo4()

# %%
## Insert your code here.

# %% [markdown]
# Display denoised iso-surface with optimal soft thresholding.

# %%
sel = 1: 2: nisosurface(Mwav(sel, sel, sel), .5)title(['Soft thresholding, SNR = ' num2str(snr(M, Mwav), 3) 'dB'])axis('off')

# %% [markdown]
# Orthogonal wavelet thresholdings suffers from blocking artifacts.This can be aleviated by performing a cycle spinning denoising, whichaverage the denosing result of translated version of the signal.A typical cycle spinning process is like this.maximum translation

# %%
w = 4

# %% [markdown]
# list of translations

# %%
[dX, dY, dZ] = ndgrid(0: w-1, 0: w-1, 0: w-1)

# %% [markdown]
# initialize spinning process

# %%
Mspin = zeros(n, n, n)

# %% [markdown]
# spin

# %%
for i in 1: w^3:    % shift the image    MnoisyC = circshift(Mnoisy, [dX(i) dY(i) dZ(i)])    % denoise the image to get a result M1    M1 = MnoisyC; % replace this line by some denoising    % shift inverse    M1 = circshift(M1, -[dX(i) dY(i) dZ(i)])    % average the result    Mspin = Mspin*(i-1)/ i + M1/ i

# %% [markdown]
# __Exercise 5__Implement cycle spinning hard thresholding with |T=3*sigma|.

# %%
solutions.exo5()

# %%
## Insert your code here.

# %% [markdown]
# Display denoised iso-surface.

# %%
sel = 1: 2: nisosurface(Mspin(sel, sel, sel), .5)title(['Cycle spinning, SNR = ' num2str(snr(M, Mspin), 3) 'dB'])axis('off')

# %% [markdown]
# Higher Order Daubechies Wavelets--------------------------------Similarely to the Haar transform, wavelets with more vanishing momentsare obtained with filtering and subsampling (pyramidal algorihtm).First we create the filters for 4 vanishing moments.

# %%
[h, g] = compute_wavelet_filter('Daubechies', 2*4)

# %% [markdown]
# Then we initialize the wavelet transform with the 3D image itself, and set the current scale.

# %%
MW = Mj = log2(n)-1

# %% [markdown]
# We transform by filtering + sub-sampling the low pass residual along the three directions.

# %%
A = MW(1: 2^(j + 1), 1: 2^(j + 1), 1: 2^(j + 1))for d in 1: 3:    a = cat(d, subsampling(cconv(A, h, d), d), subsampling(cconv(A, g, d), d))MW(1: 2^(j + 1), 1: 2^(j + 1), 1: 2^(j + 1)) = A

# %% [markdown]
# __Exercise 6__Implement the full 3D forward wavelet transform by applying these stepsfor decaying scales |j| toward 0.

# %%
solutions.exo6()

# %%
## Insert your code here.

# %% [markdown]
# Threshold the coefficients.

# %%
MWT = perform_thresholding(MW, m, 'largest')

# %% [markdown]
# Display the coefficients and thresholded coefficients for one slice.

# %%
subplot(1, 2, 1)plot_wavelet(MW(: , : , n/ 8))subplot(1, 2, 2)plot_wavelet(MWT(: , : , n/ 8))

# %% [markdown]
# Initialize the backward transform.

# %%
M1 = MWTj = 0

# %% [markdown]
# Undo one step of the wavelet transform._Note:_ |subselectdim(A,sel,1)| is equivalent to |A(sel,:,:)|while |subselectdim(A,sel,2)| is equivalent to |A(:,sel,:)|.

# %%
A = M1(1: 2^(j + 1), 1: 2^(j + 1), 1: 2^(j + 1))for d in 1: 3:    W = subselectdim(A, 2^j + 1: 2^(j + 1), d)    A = subselectdim(A, 1: 2^j, d)    A = cconv(upsampling(A, d), reverse(h), d) + cconv(upsampling(W, d), reverse(g), d)M1(1: 2^(j + 1), 1: 2^(j + 1), 1: 2^(j + 1)) = A

# %% [markdown]
# __Exercise 7__Implement the full 3D backward wavelet transform by applying these stepsfor increasing scales |j|.

# %%
solutions.exo7()

# %%
## Insert your code here.

# %% [markdown]
# Display approximated iso-surface.

# %%
sel = 1: 2: nisosurface(M1(sel, sel, sel), .5)title(['Soft thresholding, SNR = ' num2str(snr(M, M1), 3) 'dB'])axis('off')

# %% [markdown]
# Denoising Daubechies Wavelets-----------------------------Better denoising results are obtined by thresholding orthogonal waveletcoefficients.

# %% [markdown]
# __Exercise 8__Implement denoising by soft and hard thresholding Daubechies waveletcoefficients.

# %%
solutions.exo8()

# %%
## Insert your code here.

# %% [markdown]
# Display denoised iso-surface with optimal soft thresholding.

# %%
sel = 1: 2: nisosurface(Mwav(sel, sel, sel), .5)title(['Soft thresholding, SNR = ' num2str(snr(M, Mwav), 3) 'dB'])axis('off')

# %% [markdown]
# __Exercise 9__Implement cycle spinning hard thresholding with Daubechies wavelets with |T=3*sigma|.

# %%
solutions.exo9()

# %%
## Insert your code here.

# %% [markdown]
# Display denoised iso-surface.

# %%
sel = 1: 2: nisosurface(Mspin(sel, sel, sel), .5)title(['Cycle spinning, SNR = ' num2str(snr(M, Mspin), 3) 'dB'])axis('off')
